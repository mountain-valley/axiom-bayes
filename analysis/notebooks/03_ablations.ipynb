# %% [markdown]
# # Ablation Studies
#
# Replicate the ablation columns from Table 1:
# - AXIOM (fixed distance)
# - AXIOM (no BMR)
# - AXIOM (no IG)

# %%
import numpy as np
import pandas as pd
import sys
sys.path.insert(0, "../..")

from analysis.plotting import setup_style
setup_style()

# %%
# TODO: Load ablation results and generate comparison table/plots
