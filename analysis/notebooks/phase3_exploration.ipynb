# %% [markdown]
# # Phase 3: Exploration vs. Exploitation
#
# Analyze how the info-gain coefficient shapes the explore-exploit tradeoff.
# See `docs/roadmap.md` Tasks 10-12 for details.

# %%
import sys
sys.path.insert(0, '../..')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from analysis.helpers import load_results_dir, moving_average, summary_stats
from analysis.plotting import setup_style

setup_style()

# %% [markdown]
# ## Load Results

# %%
# TODO: Load results from results/info_gain_sweep/
# ig_df = load_results_dir('../../results/info_gain_sweep/')

# %% [markdown]
# ## Figure 1 (Novel): Learning Curves by Info-Gain Coefficient

# %%
# TODO: Overlay reward curves for all info_gain values (Task 12, Figure 1)

# %% [markdown]
# ## Figure 2 (Replication + Extension — Figure 4c): Utility vs Info-Gain Timeseries

# %%
# TODO: Two-panel utility + info-gain timeseries (Task 12, Figure 2)

# %% [markdown]
# ## Figure 3 (Novel): Exploration-Exploitation Transition

# %%
# TODO: Transition point vs info_gain coefficient (Task 12, Figure 3)

# %% [markdown]
# ## Figure 4 (Novel): Cumulative Reward at Early/Mid/Late Training

# %%
# TODO: Grouped bar chart (Task 12, Figure 4)

# %% [markdown]
# ## Figure 5 (Novel): Component Discovery Comparison

# %%
# TODO: Component count over time for different info_gain values (Task 12, Figure 5)
