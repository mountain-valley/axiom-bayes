# %% [markdown]
# # Phase 1: Prior and Hyperparameter Sensitivity
#
# Analyze how sMM, tMM, and rMM prior/hyperparameter settings affect AXIOM's performance.
# See `docs/roadmap.md` Tasks 2-5 for details.

# %%
import sys
sys.path.insert(0, '../..')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from analysis.helpers import load_results_dir, moving_average, summary_stats
from analysis.plotting import setup_style

setup_style()

# %% [markdown]
# ## Load Results

# %%
# TODO: Load results from results/prior_sensitivity/smm/, tmm/, rmm/
# smm_df = load_results_dir('../../results/prior_sensitivity/smm/')
# tmm_df = load_results_dir('../../results/prior_sensitivity/tmm/')
# rmm_df = load_results_dir('../../results/prior_sensitivity/rmm/')

# %% [markdown]
# ## Figure 1: Reward Sensitivity Heatmap

# %%
# TODO: Create heatmaps (Task 5, Figure 1)

# %% [markdown]
# ## Figure 2: Component Count vs Parameter Value

# %%
# TODO: Create component count plots (Task 5, Figure 2)

# %% [markdown]
# ## Figure 3: Learning Curve Comparison

# %%
# TODO: Create learning curve overlays (Task 5, Figure 3)

# %% [markdown]
# ## Figure 4: Parameter-Reward Scatter with Bayesian Interpretation

# %%
# TODO: Create annotated scatter plot (Task 5, Figure 4)
