# %% [markdown]
# # Interpretability Analysis
#
# Replicate Figure 4 from the AXIOM paper:
# - (a) Imagined trajectories and reward-conditioned rMM clusters
# - (b) rMM component count over training (BMR pruning)
# - (c) Information gain vs utility over training
# - (d) Robustness to color/shape perturbations

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, "../..")

from analysis.plotting import setup_style
setup_style()

# %%
# TODO: Load trained model and generate interpretability plots
