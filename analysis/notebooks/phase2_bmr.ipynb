# %% [markdown]
# # Phase 2: Bayesian Model Reduction Deep Dive
#
# Analyze how BMR works inside AXIOM: what gets merged, what the merge scores
# look like, and how performance compares to naive pruning.
# See `docs/roadmap.md` Tasks 6-9 for details.

# %%
import sys
sys.path.insert(0, '../..')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from analysis.helpers import load_results_dir, moving_average, summary_stats
from analysis.plotting import setup_style

setup_style()

# %% [markdown]
# ## Load Results

# %%
# TODO: Load results from results/bmr_ablation/
# bmr_df = load_results_dir('../../results/bmr_ablation/')

# %% [markdown]
# ## Figure 1 (Replication — Figure 4b): Component Count Over Time

# %%
# TODO: BMR vs no-BMR component count plot (Task 9, Figure 1)

# %% [markdown]
# ## Figure 2 (Novel): Merge-Score Distribution

# %%
# TODO: Histogram of expected free energy changes (Task 9, Figure 2)

# %% [markdown]
# ## Figure 3 (Novel): BMR Frequency and Sample-Count Sensitivity

# %%
# TODO: prune_every and bmr_samples sensitivity plots (Task 9, Figure 3)

# %% [markdown]
# ## Figure 4 (Novel): BMR vs Naive Pruning

# %%
# TODO: Comparison plot (Task 9, Figure 4)

# %% [markdown]
# ## Figure 5 (Novel): Performance vs Model Complexity

# %%
# TODO: Scatter of reward vs final component count (Task 9, Figure 5)
