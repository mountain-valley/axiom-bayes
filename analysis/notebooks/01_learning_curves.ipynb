# %% [markdown]
# # Learning Curves
#
# Replicate Figure 3 from the AXIOM paper: moving-average reward per step
# for AXIOM, BBF, and DreamerV3 on each Gameworld 10k game.

# %%
import numpy as np
import sys
sys.path.insert(0, "../..")

from analysis.plotting import plot_learning_curves, setup_style
from analysis.metrics import moving_average_reward

setup_style()

# %%
# TODO: Load results and generate plots
# results = load_results("results/")
# for game in GAME_NAMES:
#     plot_learning_curves(results, game)
